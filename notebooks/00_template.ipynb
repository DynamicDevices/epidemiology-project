# %% [markdown]
# # Notebook title
#
# ## Goal
# - Research question: TODO
# - Dataset(s): see `../docs/DATA_SOURCES.md`
# - Decisions: record in `../docs/DECISIONS.md`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from epidemiology_project.paths import raw_data_dir, processed_data_dir, figures_dir

# %% [markdown]
# ## Load data

# %%
# Example:
# df = pd.read_csv(raw_data_dir() / 'your_dataset.csv')
# df.head()
